# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import io

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  df = pd.read_csv(io.BytesIO(uploaded[fn]))
  print(df.head())
# Out:
#      <input type="file" id="files-1a4da23e-158c-439c-b5fe-6d2c5a5bc76c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a4da23e-158c-439c-b5fe-6d2c5a5bc76c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# first we observe that all females are in team A

# %% [markdown]
# then we see that all males from finance are in team B

# %%
# then we observe department vs team

import numpy as np
import matplotlib.pyplot as plt

plt.scatter(df['Team'], df['Income'])
plt.savefig("Dataset_2.jpg")
files.download("Dataset_2.jpg")
# this shows that people above 40000 are usually in team A

# %% [markdown]
# so we can conclude that if income is above 40000 they will be in team A else they will be in team B

# %%
# for the final function

def predict(income, gender, department):
  if(gender=='F'):
    team = 'A'
  elif(department=='Finance'):
    team = 'B'
  elif(income>=40000):
    team = 'A'
  else:
    team = 'B'

  print(f"Your team is {team}!")


predict(45000, 'F', 'Finance')
predict(45000, 'M', 'HR')
# Out:
# Your team is A!
# Your team is A!
